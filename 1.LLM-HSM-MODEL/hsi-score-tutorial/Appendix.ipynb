# %% [markdown]
# ## Appendix

# %% [markdown]
# Elchin Jafarov
#
# 6/2019

# %% [markdown]
# ## Why using dbh is not a good idea.
# I will be droping the age2dbh function because two references that I used for calculating dbh giving two signifincatly different results.
#
# ### References
#
# Greenberg, Cathryn H.; Simons, Robert W. 1999. Age, composition, and stand structure of old-growth oak sites in the Florida high pine landscape: implications for ecosystem management and restoration. Natural Areas Journal. 19(1): 30-40. (Figure 7)
#
# Tirpak et al., (2009) Multiscale Habitat Suitability Index Models for Priority Landbirds in the Central Hardwoods and West Gulf Coastal Plain/Ouachitas Bird Conservation Regions

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x=np.linspace(0,300,100)
plt.plot(x,(0.5-(0.817-0.004*x)**2)/0.008)
plt.plot(x, 2.77+0.31*x+0.004*x*x)
plt.legend(['Tirpak et al., (2009)','Greenberg et al., (1999)']);
plt.ylabel('dbh')
plt.xlabel('years');
