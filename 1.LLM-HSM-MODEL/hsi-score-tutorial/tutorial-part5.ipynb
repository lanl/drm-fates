# %% [markdown]
# ## HVI Tutorial (Part 5: Sensitivity Analysis)

# %% [markdown]
# Elchin Jafarov
# 6/2019
#
# ## 5. Sensitivity Analysis
# Here I setup the sensitivity analysis framework for 2 parameters (fire and mast probabilities) from LLM. I used an external package called [matk](http://dharp.github.io/matk/) to do parameter study.

# %%
import numpy as np
import LLM_model_class as llm
#import LLM_model_cpy as llm
import matplotlib.pyplot as plt
import hsi_plot_utils as hsi_plt
import time
# %matplotlib inline

#import hsiscore_class as HSI
#hsi=HSI.hsi_score()

# %%
#start_time = time.time()
#!python pstudy-matk.py
#print("--- %s seconds ---" % (time.time() - start_time))
#float((time.time() - start_time))/60

# %%
datfilename="15x15/results.dat"
slopefile="15x15/slopes.txt"
hsi_plt.barchart(datfilename,slopefile,'Scores by species for 10x10 domain')
# Out:
#           0         1         2
# 0 -0.000235 -0.000053 -0.000067
# 1 -0.000209 -0.000043  0.000015
# 2 -0.000228 -0.000029  0.000091
# 3  0.000033 -0.000056  0.000088
# 4 -0.000412 -0.000482  0.000640

# %%
datfilename="25x25/results.dat"
slopefile="25x25/slopes.txt"
hsi_plt.barchart(datfilename,slopefile,'Scores by species for 25x25 domain')
# Out:
#           0         1         2
# 0 -0.000051 -0.000040  0.000147
# 1 -0.000080 -0.000031  0.000116
# 2 -0.000084 -0.000031  0.000140
# 3 -0.000130 -0.000039  0.000103
# 4 -0.001465 -0.000504  0.000643

# %%
datfilename="50x50/results.dat"
slopefile="50x50/slopes.txt"
hsi_plt.barchart(datfilename,slopefile,'Scores by species for 50x50 domain')
# Out:
#           0         1         2
# 0 -0.000195 -0.000014  0.000054
# 1 -0.000164 -0.000012 -0.000014
# 2 -0.000232 -0.000011 -0.000040
# 3 -0.000148 -0.000022 -0.000114
# 4  0.000077 -0.001156  0.000699
